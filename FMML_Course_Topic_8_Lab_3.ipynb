# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharathi9849331596/fmml-labs/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-27 16:38:22--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   140MB/s    in 0.5s
#
# 2024-03-27 16:38:24 (140 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 31511  1803.05790v2  We present an effective dynamic clustering alg...    cs
# 1011   1509.08985v2  We seek to improve deep neural networks by gen...  stat
# 7580   1802.03938v1  Machine learning has played an important role ...  stat
# 6778   1706.01014v2  One-bit measurements widely exist in the real ...    cs
# 484    1708.09040v1  Many genres of natural language text are narra...    cs
# ...             ...                                                ...   ...
# 5606    1309.6834v1  This paper considers the problem of learning t...    cs
# 830    1706.04052v1  Monte Carlo tree search (MCTS) is extremely po...    cs
# 32272   1402.7025v2  When dealing with datasets containing a billio...    cs
# 39612  1610.04861v2  We present a novel approach of color transfer ...    cs
# 27381  1703.04977v2  There are two major types of uncertainty one c...    cs
#
#                                                    title  year  \
# 31511  Temporal Human Action Segmentation via Dynamic...  2018
# 1011   Generalizing Pooling Functions in Convolutiona...  2015
# 7580   Revisiting the Vector Space Model: Sparse Weig...  2018
# 6778   Nonconvex penalties with analytical solutions ...  2017
# 484    Modelling Protagonist Goals and Desires in Fir...  2017
# ...                                                  ...   ...
# 5606   Unsupervised Learning of Noisy-Or Bayesian Net...  2013
# 830    Beyond Monte Carlo Tree Search: Playing Go wit...  2017
# 32272  Exploiting the Statistics of Learning and Infe...  2014
# 39612                Digital Makeup from Internet Images  2016
# 27381  What Uncertainties Do We Need in Bayesian Deep...  2017
#
#                                                 keywords
# 31511  [effective, clustering, algorithm, segmentatio...
# 1011   [generalizing, operations, architectures, expl...
# 7580   [important, information, retrieval, documents,...
# 6778   [measurements, halfspaces, compressive, proces...
# 484    [narratively, structured, testament, predilect...
# ...                                                  ...
# 5606   [considers, parameters, variables, structure, ...
# 830    [extremely, determines, simulations, evaluatio...
# 32272  [containing, instances, simulations, supercomp...
# 39612  [exploring, information, collection, downloade...
# 27381  [uncertainty, aleatoric, uncertainty, observat...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 31511    [effective, clustering, algorithm, segmentatio...
# 1011     [generalizing, operations, architectures, expl...
# 7580     [important, information, retrieval, documents,...
# 6778     [measurements, halfspaces, compressive, proces...
# 484      [narratively, structured, testament, predilect...
#                                ...
# 21257    [diagnosis, identification, malfunction, obser...
# 4650     [emergence, facilitates, collection, engineeri...
# 25634    [hierarchical, recurrent, captioning, generati...
# 34739    [universal, described, percentages, percentage...
# 13123    [methodology, hypothesis, dimensional, restric...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8709 words.
# Out of those 4529 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="132eb79c-a7e5-4433-a17f-5094e03e0904" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("132eb79c-a7e5-4433-a17f-5094e03e0904")) {                    Plotly.newPlot(                        "132eb79c-a7e5-4433-a17f-5094e03e0904",                        [{"x":["clustering","algorithm","comprehensive","unsupervised","extensive","effective","applications","experiments","processing","monitoring","applicable","segmentation","parameters","implement","properties","generalized","operation","experimentally","convolutional","combining","strategies","invariance","directions","structured","themselves","architectures","operations","performance","computational","functions","approaches","exploration","demonstrate","generalizing","benchmark","conventional","particular","technique","classifiers","revisiting","documents","important","relevance","classification","information","candidate","extremely","furthermore","footprint","generalization","classifier","equivalent","generally","implementation","retrieval","representer","halfspaces","compressive","homogeneous","penalties","algorithms","analytical","efficiency","specifically","condition","comparable","measurements","different","normalization","nonconvex","including","solutions","sufficient","testament","identifying","narratives","annotations","characters","consensus","introduce","experiences","fulfilled","narrative","modelling","statements","understanding","organizing","witnessed","filtering","subsampling","degradation","reconstruction","acceleration","environments","distributions","orientation","frequencies","characterized","dependent","receptive","correlated","biological","correlations","distribution","dimensional","outperform","comparison","statistics","additional","responses","correctly","represent","controlling","uniformly","computation","significantly","estimates","resulting","pronounced","multiscale","frequency","generated","approximated","magnitude","parameter","parameterized","introduces","functional","efficiently","developed","combinations","principles","otherwise","performing","evaluation","components","correction","movements","potentially","mechanism","robustness","operating","experimental","scenarios","involving","horizontal","evaluates","deceptive","diagnosis","perturbing","sensitive","increasingly","susceptible","verification","adversarial","perturbation","significant","minimally","recording","detection","techniques","alternatives","concerning","computable","instances","practical","relations","exploiting","formulate","crowdworkers","lightweight","traditional","comparisons","demonstrating","collection","intuitions","individual","aggregated","framework","continuous","collecting","crowdsourcing","difficult","complement","regression","challenges","harnessed","practices","optimization","constraints","supervised","unintuitive","considerably","corresponding","activities","passenger","quantitatively","localization","locations","predicted"],"y":[136,833,59,120,191,223,430,646,287,32,50,214,249,76,226,78,51,52,346,105,96,19,42,91,19,116,59,879,271,214,449,55,566,18,200,123,273,246,111,12,65,343,32,509,709,57,56,165,7,122,136,51,60,121,114,1,1,17,17,5,605,21,177,196,58,99,53,762,31,11,287,172,59,1,66,8,74,20,10,353,13,4,5,47,18,164,10,5,66,3,24,94,17,93,113,23,16,32,84,15,32,43,27,215,213,116,122,66,117,35,32,108,21,22,160,293,69,153,5,10,60,175,19,64,132,19,77,44,175,199,44,41,24,78,240,96,21,17,48,123,91,28,370,95,46,4,15,5,59,1,68,52,5,29,106,13,236,8,7,332,358,24,25,10,108,124,81,57,57,0,10,166,38,36,62,4,118,11,537,103,14,13,142,19,140,112,1,11,339,142,179,1,33,124,30,1,33,56,47,41],"type":"bar"},{"x":["clustering","algorithm","comprehensive","unsupervised","extensive","effective"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4529,), (4529, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.785

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Social</span> <span style=''>Browsing</span> <span style=''>on</span> <span style=''>Flickr</span> <br/><br/><span style=''>The</span> <span style=''>new</span> <span style=''>social</span> <span style=''>media</span> <span style=''>sites</span> <span style=''>blogs</span> <span style=''>wikis</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>delicious</span> <span style=''>and</span> <span style=''>Flickr</span> <span style=''>among</span> <span style=''>others</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underscore</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3255813953488373);'>transformation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Web</span> <span style=''>to</span> <span style=''>a</span> <span style=''>participatory</span> <span style=''>medium</span> <span style=''>in</span> <span style=''>which</span> <span style=''>users</span> <span style=''>are</span> <span style=''>actively</span> <span style=''>creating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>evaluating</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>distributing</span> <span style='background-color:rgba(0, 255, 0, 0.33899905571293665);'>information</span> <span style=''>The</span> <span style=''>photo</span> <span style=''>sharing</span> <span style=''>site</span> <span style=''>Flickr</span> <span style=''>for</span> <span style=''>example</span> <span style=''>allows</span> <span style=''>users</span> <span style=''>to</span> <span style=''>upload</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>photographs</span> <span style=''>view</span> <span style=''>photos</span> <span style=''>created</span> <span style=''>by</span> <span style=''>others</span> <span style=''>comment</span> <span style=''>on</span> <span style=''>those</span> <span style=''>photos</span> <span style=''>etc</span> <span style=''>As</span> <span style=''>is</span> <span style=''>common</span> <span style=''>to</span> <span style=''>other</span> <span style=''>social</span> <span style=''>media</span> <span style=''>sites</span> <span style=''>Flickr</span> <span style=''>allows</span> <span style=''>users</span> <span style=''>to</span> <span style=''>designate</span> <span style=''>others</span> <span style=''>as</span> <span style=''>contacts</span> <span style=''>and</span> <span style=''>to</span> <span style=''>track</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activities</span> <span style=''>in</span> <span style=''>real</span> <span style=''>time</span> <span style=''>The</span> <span style=''>contacts</span> <span style=''>(or</span> <span style=''>friends)</span> <span style=''>lists</span> <span style=''>form</span> <span style=''>the</span> <span style=''>social</span> <span style=''>network</span> <span style=''>backbone</span> <span style=''>of</span> <span style=''>social</span> <span style=''>media</span> <span style=''>sites</span> <span style=''>We</span> <span style=''>claim</span> <span style=''>that</span> <span style=''>these</span> <span style=''>social</span> <span style=''>networks</span> <span style='background-color:rgba(0, 255, 0, 0.5357142857142858);'>facilitate</span> <span style=''>new</span> <span style=''>ways</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interacting</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.33899905571293665);'>information</span> <span style=''>eg</span> <span style=''>through</span> <span style=''>what</span> <span style=''>we</span> <span style=''>call</span> <span style=''>social</span> <span style=''>browsing</span> <span style=''>The</span> <span style=''>contacts</span> <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>interface</span> <span style=''>on</span> <span style=''>Flickr</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximation</span> <span style=''>Theorem</span> <span style=''>for</span> <span style=''>Mixture</span> <span style=''>of</span> <span style=''>Experts</span> <span style=''>Models</span> <br/><br/><span style=''>The</span> <span style=''>mixture</span> <span style=''>of</span> <span style=''>experts</span> <span style=''>(MoE)</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>The</span> <span style=''>class</span> <span style=''>of</span> <span style=''>MoE</span> <span style=''>mean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uniformly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergent</span> <span style=''>to</span> <span style=''>any</span> <span style=''>unknown</span> <span style=''>target</span> <span style=''>function</span> <span style=''>assuming</span> <span style=''>that</span> <span style=''>the</span> <span style=''>target</span> <span style=''>function</span> <span style=''>is</span> <span style=''>from</span> <span style=''>Sobolev</span> <span style=''>space</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sufficiently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiable</span> <span style=''>and</span> <span style=''>that</span> <span style=''>the</span> <span style=''>domain</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>is</span> <span style=''>a</span> <span style=''>compact</span> <span style=''>unit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypercube</span> <span style=''>We</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>result</span> <span style=''>which</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style=''>MoE</span> <span style=''>mean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>is</span> <span style=''>dense</span> <span style=''>in</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>compact</span> <span style=''>domains</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>Our</span> <span style=''>result</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>theorem</span> <span style=''>for</span> <span style=''>MoE</span> <span style=''>models</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Approximate</span> <span style=''>Ranking</span> <span style=''>from</span> <span style=''>Pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparisons</span> <br/><br/><span style=''>A</span> <span style=''>common</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>to</span> <span style=''>rank</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>n</span> <span style=''>items</span> <span style=''>based</span> <span style=''>on</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>Here</span> <span style=''>ranking</span> <span style=''>refers</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partitioning</span> <span style=''>the</span> <span style=''>items</span> <span style=''>into</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style=''>sizes</span> <span style='background-color:rgba(0, 255, 0, 0.47945205479452063);'>according</span> <span style=''>to</span> <span style=''>their</span> <span style=''>scores</span> <span style=''>which</span> <span style=''>includes</span> <span style='background-color:rgba(0, 255, 0, 0.3371428571428572);'>identification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>items</span> <span style=''>as</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prominent</span> <span style=''>special</span> <span style=''>case</span> <span style=''>The</span> <span style=''>score</span> <span style=''>of</span> <span style=''>a</span> <span style=''>given</span> <span style=''>item</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>that</span> <span style=''>it</span> <span style=''>beats</span> <span style=''>a</span> <span style=''>randomly</span> <span style=''>chosen</span> <span style=''>other</span> <span style=''>item</span> <span style=''>Finding</span> <span style=''>an</span> <span style=''>exact</span> <span style=''>ranking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>requires</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>prohibitively</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>but</span> <span style=''>in</span> <span style=''>practice</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>rankings</span> <span style=''>are</span> <span style=''>often</span> <span style=''>adequate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Accordingly</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>finding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>rankings</span> <span style=''>from</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparisons</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>an</span> <span style=''>active</span> <span style=''>ranking</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>counts</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='back ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Improving</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style=''>Maxout</span> <span style=''>Units</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>variant</span> <span style=''>of</span> <span style=''>the</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>maxout</span> <span style=''>unit</span> <span style=''>The</span> <span style=''>success</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>utilizing</span> <span style=''>maxout</span> <span style=''>can</span> <span style=''>partly</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributed</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>favorable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>under</span> <span style=''>dropout</span> <span style=''>when</span> <span style=''>compared</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>rectified</span> <span style=''>linear</span> <span style=''>units</span> <span style=''>It</span> <span style=''>however</span> <span style=''>also</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>the</span> <span style=''>fact</span> <span style=''>that</span> <span style=''>each</span> <span style=''>maxout</span> <span style=''>unit</span> <span style=''>performs</span> <span style=''>a</span> <span style=''>pooling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operation</span> <span style=''>over</span> <span style=''>a</span> <span style=''>group</span> <span style=''>of</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformations</span> <span style=''>and</span> <span style=''>is</span> <span style=''>thus</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>to</span> <span style=''>changes</span> <span style=''>in</span> <span style=''>its</span> <span style=''>input</span> <span style=''>Starting</span> <span style=''>from</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observation</span> <span style=''>we</span> <span style=''>ask</span> <span style=''>the</span> <span style=''>question</span> <span style=''>Can</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>maxout</span> <span style=''>units</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preserved</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>maxout</span> <span style=''>(probout)</span> <span style=''>units</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>achieve</span> <span style=''>this</span> <span style=''>balance</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quan ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.1026099392205935)
# 	experimental (0.1322845906328209)
# 	knowledge (0.12870933142652843)
# 	architecture (0.09653199856989632)
# 	segmentation (0.07651054701465856)
# 	detection (0.11869860564890955)
# 	convolutional (0.12370396853771898)
# 	information (0.2534858777261351)
# 	different (0.27243475151948515)
# 	recognition (0.13156953879156238)
#
# Some Statistics words are:
# 	distributions (0.12281577633549676)
# 	variables (0.13729405891163254)
# 	statistical (0.15426859710434349)
# 	distribution (0.17324013979031452)
# 	theoretical (0.15227159261108336)
# 	estimation (0.1782326510234648)
# 	algorithm (0.4038941587618572)
# 	dimensional (0.1832251622566151)
# 	inference (0.19321018472291562)
# 	regression (0.17324013979031452)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3021a65f-f613-4b29-9a03-9e4c0c2918f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3021a65f-f613-4b29-9a03-9e4c0c2918f1")) {                    Plotly.newPlot(                        "3021a65f-f613-4b29-9a03-9e4c0c2918f1",                        [{"x":["clustering","algorithm","comprehensive","unsupervised","extensive","effective","applications","experiments","processing","monitoring","applicable","segmentation","parameters","implement","properties","generalized","operation","experimentally","convolutional","combining","strategies","invariance","directions","structured","themselves","architectures","operations","performance","computational","functions","approaches","exploration","demonstrate","generalizing","benchmark","conventional","particular","technique","classifiers","revisiting","documents","important","relevance","classification","information","candidate","extremely","furthermore","footprint","generalization","classifier","equivalent","generally","implementation","retrieval","representer","halfspaces","compressive","homogeneous","penalties","algorithms","analytical","efficiency","specifically","condition","comparable","measurements","different","normalization","nonconvex","including","solutions","sufficient","testament","identifying","narratives","annotations","characters","consensus","introduce","experiences","fulfilled","narrative","modelling","statements","understanding","organizing","witnessed","filtering","subsampling","degradation","reconstruction","acceleration","environments","distributions","orientation","frequencies","characterized","dependent","receptive","correlated","biological","correlations","distribution","dimensional","outperform","comparison","statistics","additional","responses","correctly","represent","controlling","uniformly","computation","significantly","estimates","resulting","pronounced","multiscale","frequency","generated","approximated","magnitude","parameter","parameterized","introduces","functional","efficiently","developed","combinations","principles","otherwise","performing","evaluation","components","correction","movements","potentially","mechanism","robustness","operating","experimental","scenarios","involving","horizontal","evaluates","deceptive","diagnosis","perturbing","sensitive","increasingly","susceptible","verification","adversarial","perturbation","significant","minimally","recording","detection","techniques","alternatives","concerning","computable","instances","practical","relations","exploiting","formulate","crowdworkers","lightweight","traditional","comparisons","demonstrating","collection","intuitions","individual","aggregated","framework","continuous","collecting","crowdsourcing","difficult","complement","regression","challenges","harnessed","practices","optimization","constraints","supervised","unintuitive","considerably","corresponding","activities","passenger","quantitatively","localization","locations","predicted","evaluated","extracting","hourglass","estimation","extracted","qualitatively","positives","distraction","attention","occlusion","transformation","procedures","statistic","correlation","inequalities","elementary","elliptical","semiparametric","parametric","connected","estimators","estimator","population","empirical","numerical","investigated","propagate","randomized","distributed","respectively","surpasses","efficient","functionals","previously","establish","decentralized","extending","simultaneously","observations","favorable","averaging","asynchronous","synchronous","convergence","iterations","essential","difference","statistical","expensive","introduced","component","dictionary","hyperspectral","factorization","complexity","iteratively","streaming" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	crowdworkers
# 	elliptical
# 	semiparametric
# 	commonplace
# 	multiplying
# 	gracefully
# 	homeostasis
# 	dangerous
# 	metabolic
# 	underestimates
# 	quantiles
# 	lancaster
# 	eigenvalue
# 	microarray
# 	exponentiated
# 	emphmulti
# 	distributionally
# 	bivariate
# 	nonparametrics
# 	exemplifies
# Some words which never appear in Statistics papers:
# 	narratives
# 	witnessed
# 	deceptive
# 	hourglass
# 	distraction
# 	attentive
# 	commitment
# 	quantifiers
# 	operational
# 	propositional
# 	circumscription
# 	monocular
# 	synchronously
# 	axiomatization
# 	upsampling
# 	downsampling
# 	satisfiable
# 	representable
# 	corrective
# 	switchboard

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077017754392443e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7416666666666667
